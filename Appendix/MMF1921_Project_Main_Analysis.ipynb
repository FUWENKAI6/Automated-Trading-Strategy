# %%
import time
import math
from scipy.stats import gmean
import matplotlib.pyplot as plt
from services.project_function2 import *
import pandas as pd

adjClose = pd.read_csv("MMF1921_AssetPrices_3.csv", index_col=0)
factorRet = pd.read_csv("MMF1921_FactorReturns_3.csv", index_col=0)

adjClose.index = pd.to_datetime(adjClose.index)
factorRet.index = pd.to_datetime(factorRet.index)

# Initial budget to invest ($100,000)
initialVal = 100000

# Length of investment period (in months)
investPeriod = 6

factorRet = factorRet

#rf and factor returns
riskFree = factorRet['RF']
factorRet = factorRet.loc[:, factorRet.columns != 'RF']

#Identify the tickers and the dates
tickers = adjClose.columns
dates   = factorRet.index

# Calculate the stocks monthly excess returns
# pct change and drop the first null observation
returns = adjClose.pct_change(1).iloc[1:, :]
returns = returns - np.diag(riskFree.values) @ np.ones_like(returns.values)
# Align the price table to the asset and factor returns tables by discarding the first observation.
adjClose = adjClose.iloc[1:, :]

assert adjClose.index[0] == returns.index[0]
assert adjClose.index[0] == factorRet.index[0]

# List of strategies
strategies = ['OLS_robustMVO', 'FF_robustMVO','LASSO_robustMVO', 'BSS_robustMVO']

# Measure runtime: start the clock
start_time = time.time()

portfValue_dict = {}
turnover_dict = {}
SR_dict = {}
avgTurnover_dict = {}

for strategy in strategies:
    print(f"Processing strategy: {strategy}")

    # Start of out-of-sample test period
    testStart = returns.index[0] + pd.offsets.DateOffset(years=5)

    #End of the first investment period
    testEnd = testStart + pd.offsets.DateOffset(months=investPeriod) -  pd.offsets.DateOffset(days = 1)

    # End of calibration period
    calEnd = testStart -  pd.offsets.DateOffset(days = 1)

    # Total number of investment periods
    NoPeriods = math.ceil((returns.index[-1].to_period('M') - testStart.to_period('M')).n / investPeriod)

    # Number of assets
    n  = len(tickers)

    # Preallocate space for the portfolio weights (x0 will be used to calculate
    # the turnover rate)
    x  = np.zeros([n, NoPeriods])
    x0 = np.zeros([n, NoPeriods])

    # Preallocate space for the portfolio per period value and turnover
    currentVal = np.zeros([NoPeriods, 1])
    turnover   = np.zeros([NoPeriods, 1])

    #Initiate counter for the number of observations per investment period
    toDay = 0

    # Measure runtime: start the clock
    start_time = time.time()

    # Empty list to measure the value of the portfolio over the period
    portfValue = []

    for t in range(NoPeriods):
        # Subset the returns and factor returns corresponding to the current calibration period.
        periodReturns = returns[returns.index <= calEnd]
        periodFactRet = factorRet[factorRet.index <= calEnd]

        current_price_idx = (calEnd - pd.offsets.DateOffset(months=1) <= adjClose.index)&(adjClose.index <= calEnd)
        currentPrices = adjClose[current_price_idx]

        # Subset the prices corresponding to the current out-of-sample test period.
        periodPrices_idx = (testStart <= adjClose.index)&(adjClose.index <= testEnd)
        periodPrices = adjClose[periodPrices_idx]

        assert len(periodPrices) == investPeriod
        assert len(currentPrices) == 1
        # Set the initial value of the portfolio or update the portfolio value
        if t == 0:
            currentVal[0] = initialVal
        else:
            currentVal[t] = currentPrices @  NoShares.values.T
            #Store the current asset weights (before optimization takes place)
            x0[:,t] = currentPrices.values*NoShares.values/currentVal[t]

        #----------------------------------------------------------------------
        # Portfolio optimization
        # You must write code your own algorithmic trading function
        # The project function is in the services folder
        # Take in the period returns and period factor returns and produce
        # an allocation
        #----------------------------------------------------------------------
        x[:,t] = project_function(periodReturns, periodFactRet, x0, strategy)

        #Calculate the turnover rate
        if t > 0:
            turnover[t] = np.sum( np.abs( x[:,t] - x0[:,t] ) )

        # Number of shares your portfolio holds per stock
        NoShares = x[:,t]*currentVal[t]/currentPrices

        # Update counter for the number of observations per investment period
        fromDay = toDay
        toDay   = toDay + len(periodPrices)

        # Weekly portfolio value during the out-of-sample window
        portfValue.append(periodPrices@ NoShares.values.T)

        # Update your calibration and out-of-sample test periods
        testStart = testStart + pd.offsets.DateOffset(months=investPeriod)
        testEnd   = testStart + pd.offsets.DateOffset(months=investPeriod) - pd.offsets.DateOffset(days=1)
        calEnd    = testStart - pd.offsets.DateOffset(days=1)

    portfValue = pd.concat(portfValue, axis = 0)
    end_time = time.time()
    #--------------------------------------------------------------------------
    # 3.1 Calculate the portfolio average return, standard deviation, Sharpe ratio and average turnover.
    #-----------------------------------------------------------------------
    # Calculate the observed portfolio returns
    portfRets = portfValue.pct_change(1).iloc[1:,:]

    # Calculate the portfolio excess returns
    portfExRets = portfRets.subtract(riskFree[(riskFree.index >= portfRets.index[0])&(riskFree.index <= portfRets.index[-1])], axis = 0)

    # Calculate the portfolio Sharpe ratio
    SR = ((portfExRets + 1).apply(gmean, axis=0) - 1)/portfExRets.std()

    # Calculate the average turnover rate
    avgTurnover = np.mean(turnover[1:])

    #Print Sharpe ratio and Avg. turnover to the console
    print("Elasped time is "+ str(end_time - start_time) + ' seconds')
    print('Sharpe ratio: ', str(SR[0]))
    print('Avg. turnover: ', str(avgTurnover))

# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# % Program End
# Out:
# Processing strategy: OLS_robustMVO
# Elasped time is 0.4216647148132324 seconds
# Sharpe ratio:  0.23620683725137911
# Avg. turnover:  0.32459297537932863
# Processing strategy: FF_robustMVO
# Elasped time is 0.6293618679046631 seconds
# Sharpe ratio:  0.23611783307319673
# Avg. turnover:  0.3559393679892441
# Processing strategy: LASSO_robustMVO
# Elasped time is 3.7243571281433105 seconds
# Sharpe ratio:  0.23517106341353552
# Avg. turnover:  0.34547333873147734
# Processing strategy: BSS_robustMVO
# Restricted license - for non-production use only - expires 2025-11-24
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22621.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i5-13500H, instruction set [SSE2|AVX|AVX2]
# Thread count: 12 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 19 rows, 18 columns and 45 nonzeros
# Model fingerprint: 0x8c3578a5
# Model has 45 quadratic objective terms
# Variable types: 9 continuous, 9 integer (9 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+02]
#   Objective range  [2e-02, 8e-01]
#   QObjective range [2e-03, 7e+01]
#   Bounds range     [1e+00, 2e+01]
#   RHS range        [6e+00, 6e+00]
# Presolve time: 0.01s
# Presolved: 19 rows, 18 columns, 45 nonzeros
# Presolved model has 45 quadratic objective terms
# Variable types: 9 continuous, 9 integer (9 binary)
# Found heuristic solution: objective 0.1099143
#
# Root relaxation: objective 1.090705e-01, 48 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.10907    0    4    0.10991    0.10907  0.77%     -    0s
# H    0     0                       0.1098000    0.10907  0.66%     -    0s
# H    0     0                       0.1094269    0.10907  0.33%     -    0s
#      0     0    0.10923    0    4    0.10943    0.10923  0.18%     -    0s
#      0     0    0.10923    0    4    0.10943    0.10923  0.18%     -    0s
#      0     0    0.10923    0    4    0.10943    0.10923  0.18%     -    0s
#      0     0    0.10923    0    4    0.10943    0.10923  0.18%     -    0s
#      0     2    0.10923    0    4    0.10943    0.10923  0.18%     -    0s
# *    6     3               3       0.1092470    0.10923  0.01%   4.5    0s
#
# Explored 14 nodes (113 simplex iterations) in 0.11 seconds (0.00 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 4: 0.109247 0.109427 0.1098 0.109914
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.092470060104e-01, best bound 1.092470060104e-01, gap 0.0000%
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22621.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i5-13500H, instruction set [SSE2|AVX|AVX2]
# Thread count: 12 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 19 rows, 18 columns and 45 nonzeros
# Model fingerprint: 0x85cc3cab
# Model has 45 quadratic objective terms
# Variable types: 9 continuous, 9 integer (9 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+02]
#   Objective range  [3e-03, 2e-01]
#   QObjective range [2e-03, 7e+01]
#   Bounds range     [1e+00, 2e+01]
#   RHS range        [6e+00, 6e+00]
# Presolve time: 0.00s
# Presolved: 19 rows, 18 columns, 45 nonzeros
# Presolved model has 45 quadratic objective terms
# Variable types: 9 continuous, 9 integer (9 binary)
# Found heuristic solution: objective 0.1465144
#
# Root relaxation: objective 1.458152e-01, 46 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.14582    0    4    0.14651    0.14582  0.48%     -    0s
# H    0     0                       0.1463890    0.14582  0.39%     -    0s
#      0     0    0.14582    0    4    0.14639    0.14582  0.39%     -    0s
#      0     0    0.14582    0    4    0.14639    0.14582  0.39%     -    0s
#      0     0    0.14582    0    4    0.14639    0.14582  0.39%     -    0s
#      0     0    0.14597    0    4    0.14639    0.14597  0.29%     -    0s
# H    0     0                       0.1463692    0.14597  0.27%     -    0s
# H    0     0                       0.1459849    0.14597  0.01%     -    0s
#      0     0          -    0         0.14598    0.14598  0.00%     -    0s
#
# Explored 1 nodes (65 simplex iterations) in 0.07 seconds (0.00 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 3: 0.145985 0.146369 0.146514
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.459848557736e-01, best bound 1.459842997431e-01, gap 0.0004%
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22621.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i5-13500H, instruction set [SSE2|AVX|AVX2]
# Thread count: 12 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 19 rows, 18 columns and 45 nonzeros
# Model fingerprint: 0x3b945ec3
# Model has 45 quadratic objective terms
# Variable types: 9 continuous, 9 integer (9 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+02]
#   Objective range  [1e-03, 1e+00]
#   QObjective range [2e-03, 7e+01]
#   Bounds range     [1e+00, 2e+01]
#   RHS range        [6e+00, 6e+00]
# Presolve time: 0.00s
# Presolved: 19 rows, 18 columns, 45 nonzeros
# Presolved model has 45 quadratic objective terms
# Variable types: 9 continuous, 9 integer (9 binary)
# Found heuristic solution: objective 0.2772272
#
# Root relaxation: objective 2.399497e-01, 52 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.23995    0    4    0.27723    0.23995  13.4%     -    0s
# H    0     0                       0.2580138    0.23995  7.00%     -    0s
#      0     0    0.25116    0    4    0.25801    0.25116  2.65%     -    0s
#      0     0    0.25116    0    4    0.25801    0.25116  2.65%     -    0s
# H    0     0                       0.2566978    0.25116  2.16%     -    0s
#      0     1    0.25116    0    4    0.25670    0.25116  2.16%     -    0s
#
# Explored 18 nodes (119 simplex iterations) in 0.07 seconds (0.00 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 3: 0.256698 0.258014 0.277227
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.566977563425e-01, best bound 2.566977563425e-01, gap 0.0000%
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22621.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i5-13500H, instruction set [SSE2|AVX|AVX2]
# Thread count: 12 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 19 rows, 18 columns and 45 nonzeros
# Model fingerprint: 0xc9b9cfb3
# Model has 45 quadratic objective terms
# Variable types: 9 continuous, 9 integer (9 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+02]
#   Objective range  [9e-03, 7e-01]
#   QObjective range [2e-03, 7e+01]
#   Bounds range     [1e+00, 2e+01]
#   RHS range        [6e+00, 6e+00]
# Presolve time: 0.00s
# Presolved: 19 rows, 18 columns, 45 nonzeros
# Presolved model has 45 quadratic objective terms
# Variable types: 9 continuous, 9 integer (9 binary)
# Found heuristic solution: objective 0.1088727
#
# Root relaxation: objective 9.080476e-02, 42 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.09080    0    4    0.10887    0.09080  16.6%     -    0s
# H    0     0                       0.1015534    0.09080  10.6%     -    0s
# H    0     0                       0.0970335    0.09152  5.68%     -    0s
#      0     0    0.09152    0    4    0.09703    0.09152  5.68%     -    0s
#      0     0    0.09152    0    4    0.09703    0.09152  5.68%     -    0s
#      0     2    0.09152    0    4    0.09703    0.09152  5.68%     -    0s
#
# Explored 16 nodes (103 simplex iterations) in 0.10 seconds (0.00 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 3: 0.0970335 0.101553 0.108873
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.703349875485e-02, best bound 9.703349875485e-02, gap 0.0000%
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22621.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i5-13500H, instruction set [SSE2|AVX|AVX2]
# Thread count: 12 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 19 rows, 18 columns and 45 nonzeros
# Model fingerprint: 0xfa6f3e94
# Model has 45 quadratic objective terms
# Variable types: 9 continuous, 9 integer (9 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+02]
#   Objective range  [2e-02, 5e-01]
#   QObjective range [2e-03, 7e+01]
#   Bounds range     [1e+00, 2e+01]
#   RHS range        [6e+00, 6e+00]
# Presolve time: 0.00s
# Presolved: 19 rows, 18 columns, 45 nonzeros
# Presolved model has 45 quadratic objective terms
# Variable types: 9 continuous, 9 integer (9 binary)
# Found heuristic solution: objective 0.3068189
# Found heuristic solution: objective 0.2520006
#
# Root relaxation: objective 2.281981e-01, 40 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.22820    0    4    0.25200    0.22820  9.45%     -    0s
# H    0     0                       0.2304650    0.22820  0.98%     -    0s
#      0     0    0.22939    0    4    0.23047    0.22939  0.47%     -    0s
# H    0     0                       0.2304214    0.22939  0.45%     -    0s
#      0     1    0.22939    0    4    0.23042    0.22939  0.45%     -    0s
# H    5     5                       0.2295433    0.22939  0.07%   3.6    0s
#
# Explored 11 nodes (70 simplex iterations) in 0.10 seconds (0.00 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 5: 0.229543 0.230421 0.230465 ... 0.306819
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.295432678671e-01, best bound 2.295432678671e-01, gap 0.0000%
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22621.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i5-13500H, instruction set [SSE2|AVX|AVX2]
# Thread count: 12 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 19 rows, 18 columns and 45 nonzeros
# Model fingerprint: 0x0475fc7f
# Model has 45 quadratic objective terms
# Variable types: 9 continuous, 9 integer (9 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+02]
#   Objective range  [1e-02, 3e+00]
#   QObjective range [2e-03, 7e+01]
#   Bounds range     [1e+00, 2e+01]
#   RHS range        [6e+00, 6e+00]
# Presolve time: 0.00s
# Presolved: 19 rows, 18 columns, 45 nonzeros
# Presolved model has 45 quadratic objective terms
# Variable types: 9 continuous, 9 integer (9 binary)
# Found heuristic solution: objective 0.2111595
#
# Root relaxation: objective 1.862919e-01, 50 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.18629    0    4    0.21116    0.18629  11.8%     -    0s
#      0     0    0.18648    0    4    0.21116    0.18648  11.7%     -    0s
#      0     0    0.18648    0    4    0.21116    0.18648  11.7%     -    0s
# H    0     0                       0.1948725    0.18648  4.31%     -    0s
# H    0     2                       0.1916557    0.18648  2.70%     -    0s
#      0     2    0.18648    0    4    0.19166    0.18648  2.70%     -    0s
# H    5     1                       0.1902601    0.18963  0.33%   5.6    0s
#
# Explored 6 nodes (88 simplex iterations) in 0.08 seconds (0.00 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 4: 0.19026 0.191656 0.194873 0.211159
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.902600887667e-01, best bound 1.902600887667e-01, gap 0.0000%
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22621.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i5-13500H, instruction set [SSE2|AVX|AVX2]
# Thread count: 12 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 19 rows, 18 columns and 45 nonzeros
# Model fingerprint: 0x6776761a
# Model has 45 quadratic objective terms
# Variable types: 9 continuous, 9 integer (9 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+02]
#   Objective range  [8e-04, 1e-01]
#   QObjective range [2e-03, 7e+01]
#   Bounds range     [1e+00, 2e+01]
#   RHS range        [6e+00, 6e+00]
# Presolve time: 0.00s
# Presolved: 19 rows, 18 columns, 45 nonzeros
# Presolved model has 45 quadratic objective terms
# Variable types: 9 continuous, 9 integer (9 binary)
# Found heuristic solution: objective 0.0747593
#
# Root relaxation: objective 5.666569e-02, 42 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.05667    0    4    0.07476    0.05667  24.2%     -    0s
# H    0     0                       0.0619796    0.05667  8.57%     -    0s
# H    0     0                       0.0603678    0.05667  6.13%     -    0s
#      0     0    0.05667    0    4    0.06037    0.05667  6.13%     -    0s
#      0     2    0.05667    0    4    0.06037    0.05667  6.13%     -    0s
# H    4     4                       0.0589873    0.05667  3.94%   4.0    0s
# H    9     7                       0.0589283    0.05667  3.84%   3.2    0s
# *   20     0               6       0.0572313    0.05723  0.00%   3.9    0s
#
# Explored 23 nodes (124 simplex iterations) in 0.10 seconds (0.00 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 5: 0.0572313 0.0589283 0.0589873 ... 0.0747593
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.723127079259e-02, best bound 5.723127079259e-02, gap 0.0000%
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22621.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i5-13500H, instruction set [SSE2|AVX|AVX2]
# Thread count: 12 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 19 rows, 18 columns and 45 nonzeros
# Model fingerprint: 0x015a4c0e
# Model has 45 quadratic objective terms
# Variable types: 9 continuous, 9 integer (9 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+02]
#   Objective range  [1e-02, 9e-02]
#   QObjective range [2e-03, 7e+01]
#   Bounds range     [1e+00, 2e+01]
#   RHS range        [6e+00, 6e+00]
# Presolve time: 0.00s
# Presolved: 19 rows, 18 columns, 45 nonzeros
# Presolved model has 45 quadratic objective terms
# Variable types: 9 continuous, 9 integer (9 binary)
# Found heuristic solution: objective 0.0778550
#
# Root relaxation: objective 5.610631e-02, 44 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.05611    0    4    0.07786    0.05611  27.9%     -    0s
# H    0     0                       0.0772839    0.05611  27.4%     -    0s
# H    0     0                       0.0644269    0.05611  12.9%     -    0s
# H    0     0                       0.0591507    0.05611  5.15%     -    0s
#      0     0    0.05878    0    4    0.05915    0.05878  0.63%     -    0s
#      0     0    0.05878    0    4    0.05915    0.05878  0.63%     -    0s
#      0     0    0.05878    0    4    0.05915    0.05878  0.63%     -    0s
#      0     2    0.05878    0    4    0.05915    0.05878  0.63%     -    0s
#
# Explored 10 nodes (90 simplex iterations) in 0.10 seconds (0.00 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 3: 0.0591507 0.0644269 0.077855
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.915069436365e-02, best bound 5.915069436365e-02, gap 0.0000%
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22621.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i5-13500H, instruction set [SSE2|AVX|AVX2]
# Thread count: 12 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 19 rows, 18 columns and 45 nonzeros
# Model fingerprint: 0x7656c07c
# Model has 45 quadratic objective terms
# Variable types: 9 continuous, 9 integer (9 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+02]
#   Objective range  [7e-03, 2e-01]
#   QObjective range [2e-03, 7e+01]
#   Bounds range     [1e+00, 2e+01]
#   RHS range        [6e+00, 6e+00]
# Presolve time: 0.00s
# Presolved: 19 rows, 18 columns, 45 nonzeros
# Presolved model has 45 quadratic objective terms
# Variable types: 9 continuous, 9 integer (9 binary)
# Found heuristic solution: objective 0.1131288
#
# Root relaxation: objective 1.088118e-01, 40 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.10881    0    4    0.11313    0.10881  3.82%     -    0s
#      0     0    0.11150    0    4    0.11313    0.11150  1.44%     -    0s
#      0     0    0.11150    0    4    0.11313    0.11150  1.44%     -    0s
#      0     2    0.11150    0    4    0.11313    0.11150  1.44%     -    0s
# H    4     2                       0.1127322    0.11150  1.09%   3.0    0s
# *   13     1               5       0.1127135    0.11182  0.79%   3.5    0s
# *   14     0               6       0.1118295    0.11183  0.00%   3.6    0s
#
# Explored 15 nodes (101 simplex iterations) in 0.10 seconds (0.00 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 4: 0.11183 0.112714 0.112732 0.113129
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.118295266923e-01, best bound 1.118295266923e-01, gap 0.0000%
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22621.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i5-13500H, instruction set [SSE2|AVX|AVX2]
# Thread count: 12 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 19 rows, 18 columns and 45 nonzeros
# Model fingerprint: 0x872d4f62
# Model has 45 quadratic objective terms
# Variable types: 9 continuous, 9 integer (9 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+02]
#   Objective range  [1e-03, 7e-01]
#   QObjective range [2e-03, 7e+01]
#   Bounds range     [1e+00, 2e+01]
#   RHS range        [6e+00, 6e+00]
# Presolve time: 0.00s
# Presolved: 19 rows, 18 columns, 45 nonzeros
# Presolved model has 45 quadratic objective terms
# Variable types: 9 continuous, 9 integer (9 binary)
# Found heuristic solution: objective 0.0424196
#
# Root relaxation: objective 3.990073e-02, 46 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.03990    0    4    0.04242    0.03990  5.94%     -    0s
# H    0     0                       0.0423738    0.03990  5.84%     -    0s
# H    0     0                       0.0403483    0.03990  1.11%     -    0s
# H    0     0                       0.0403458    0.03990  1.10%     -    0s
#      0     0    0.03990    0    4    0.04035    0.03990  1.10%     -    0s
#      0     0    0.03990    0    4    0.04035    0.03990  1.10%     -    0s
# H    0     0                       0.0401242    0.03990  0.56%     -    0s
#      0     1    0.03990    0    4    0.04012    0.03990  0.56%     -    0s
# *    4     2               3       0.0399936    0.03998  0.03%   5.8    0s
#
# Explored 7 nodes (77 simplex iterations) in 0.11 seconds (0.00 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 5: 0.0399936 0.0401242 0.0403458 ... 0.0424196
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.999362296328e-02, best bound 3.999362296328e-02, gap 0.0000%
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22621.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i5-13500H, instruction set [SSE2|AVX|AVX2]
# Thread count: 12 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 19 rows, 18 columns and 45 nonzeros
# Model fingerprint: 0x883b3284
# Model has 45 quadratic objective terms
# Variable types: 9 continuous, 9 integer (9 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+02]
#   Objective range  [1e-02, 3e+00]
#   QObjective range [2e-03, 7e+01]
#   Bounds range     [1e+00, 2e+01]
#   RHS range        [6e+00, 6e+00]
# Presolve time: 0.00s
# Presolved: 19 rows, 18 columns, 45 nonzeros
# Presolved model has 45 quadratic objective terms
# Variable types: 9 continuous, 9 integer (9 binary)
# Found heuristic solution: objective 0.2180416
#
# Root relaxation: objective 2.175962e-01, 46 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.21760    0    4    0.21804    0.21760  0.20%     -    0s
#      0     0    0.21780    0    4    0.21804    0.21780  0.11%     -    0s
#      0     0    0.21780    0    4    0.21804    0.21780  0.11%     -    0s
#      0     0    0.21780    0    4    0.21804    0.21780  0.11%     -    0s
#      0     2    0.21780    0    4    0.21804    0.21780  0.11%     -    0s
#
# Explored 10 nodes (91 simplex iterations) in 0.09 seconds (0.00 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 0.218042
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.180416267670e-01, best bound 2.180416267670e-01, gap 0.0000%
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22621.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i5-13500H, instruction set [SSE2|AVX|AVX2]
# Thread count: 12 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 19 rows, 18 columns and 45 nonzeros
# Model fingerprint: 0x9c6dadb9
# Model has 45 quadratic objective terms
# Variable types: 9 continuous, 9 integer (9 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+02]
#   Objective range  [9e-03, 2e+00]
#   QObjective range [2e-03, 7e+01]
#   Bounds range     [1e+00, 2e+01]
#   RHS range        [6e+00, 6e+00]
# Presolve time: 0.00s
# Presolved: 19 rows, 18 columns, 45 nonzeros
# Presolved model has 45 quadratic objective terms
# Variable types: 9 continuous, 9 integer (9 binary)
# Found heuristic solution: objective 0.0665452
#
# Root relaxation: objective 6.098208e-02, 45 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.06098    0    4    0.06655    0.06098  8.36%     -    0s
#      0     0    0.06116    0    4    0.06655    0.06116  8.10%     -    0s
#      0     2    0.06116    0    4    0.06655    0.06116  8.10%     -    0s
# H    4     3                       0.0648842    0.06116  5.74%   3.0    0s
# H   16     2                       0.0648725    0.06149  5.21%   3.5    0s
# *   17     2               6       0.0614933    0.06149  0.00%   3.8    0s
#
# Explored 19 nodes (112 simplex iterations) in 0.10 seconds (0.00 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 4: 0.0614933 0.0648725 0.0648842 0.0665452
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.149331143385e-02, best bound 6.149331143385e-02, gap 0.0000%
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22621.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i5-13500H, instruction set [SSE2|AVX|AVX2]
# Thread count: 12 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 19 rows, 18 columns and 45 nonzeros
# Model fingerprint: 0x78949694
# Model has 45 quadratic objective terms
# Variable types: 9 continuous, 9 integer (9 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+02]
#   Objective range  [7e-03, 3e-01]
#   QObjective range [2e-03, 7e+01]
#   Bounds range     [1e+00, 2e+01]
#   RHS range        [6e+00, 6e+00]
# Presolve time: 0.00s
# Presolved: 19 rows, 18 columns, 45 nonzeros
# Presolved model has 45 quadratic objective terms
# Variable types: 9 continuous, 9 integer (9 binary)
# Found heuristic solution: objective 0.0551210
#
# Root relaxation: objective 5.457404e-02, 48 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.05457    0    4    0.05512    0.05457  0.99%     -    0s
# H    0     0                       0.0550392    0.05457  0.85%     -    0s
#      0     0    0.05471    0    4    0.05504    0.05471  0.61%     -    0s
#      0     0    0.05471    0    4    0.05504    0.05471  0.61%     -    0s
#      0     2    0.05471    0    4    0.05504    0.05471  0.61%     -    0s
# *   18     2               6       0.0549064    0.05471  0.37%   3.7    0s
# *   23     0               7       0.0547583    0.05476  0.00%   3.7    0s
#
# Explored 25 nodes (139 simplex iterations) in 0.10 seconds (0.00 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 4: 0.0547583 0.0549064 0.0550392 0.055121
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.475827126850e-02, best bound 5.475827126850e-02, gap 0.0000%
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22621.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i5-13500H, instruction set [SSE2|AVX|AVX2]
# Thread count: 12 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 19 rows, 18 columns and 45 nonzeros
# Model fingerprint: 0xb7281b7a
# Model has 45 quadratic objective terms
# Variable types: 9 continuous, 9 integer (9 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+02]
#   Objective range  [2e-03, 7e-01]
#   QObjective range [2e-03, 7e+01]
#   Bounds range     [1e+00, 2e+01]
#   RHS range        [6e+00, 6e+00]
# Presolve time: 0.00s
# Presolved: 19 rows, 18 columns, 45 nonzeros
# Presolved model has 45 quadratic objective terms
# Variable types: 9 continuous, 9 integer (9 binary)
# Found heuristic solution: objective 0.1249638
#
# Root relaxation: objective 1.021250e-01, 40 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.10212    0    4    0.12496    0.10212  18.3%     -    0s
# H    0     0                       0.1121313    0.10212  8.92%     -    0s
# H    0     0                       0.1120268    0.10212  8.84%     -    0s
# H    0     0                       0.1093264    0.10212  6.59%     -    0s
#      0     0    0.10212    0    4    0.10933    0.10212  6.59%     -    0s
#      0     0    0.10212    0    4    0.10933    0.10212  6.59%     -    0s
#      0     0    0.10212    0    4    0.10933    0.10212  6.59%     -    0s
#      0     2    0.10212    0    4    0.10933    0.10212  6.59%     -    0s
# H    3     6                       0.1090813    0.10212  6.38%   3.7    0s
# H    5     6                       0.1047000    0.10212  2.46%   4.0    0s
# *    9     2               3       0.1025676    0.10257  0.00%   3.8    0s
#
# Explored 11 nodes (85 simplex iterations) in 0.11 seconds (0.00 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 7: 0.102568 0.1047 0.109081 ... 0.124964
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.025676310316e-01, best bound 1.025676310316e-01, gap 0.0000%
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22621.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i5-13500H, instruction set [SSE2|AVX|AVX2]
# Thread count: 12 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 19 rows, 18 columns and 45 nonzeros
# Model fingerprint: 0xfd5d34d6
# Model has 45 quadratic objective terms
# Variable types: 9 continuous, 9 integer (9 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+02]
#   Objective range  [1e-03, 1e+00]
#   QObjective range [2e-03, 7e+01]
#   Bounds range     [1e+00, 2e+01]
#   RHS range        [6e+00, 6e+00]
# Presolve time: 0.00s
# Presolved: 19 rows, 18 columns, 45 nonzeros
# Presolved model has 45 quadratic objective terms
# Variable types: 9 continuous, 9 integer (9 binary)
# Found heuristic solution: objective 0.0376096
#
# Root relaxation: objective 3.315261e-02, 46 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.03315    0    4    0.03761    0.03315  11.9%     -    0s
# H    0     0                       0.0366379    0.03315  9.51%     -    0s
# H    0     0                       0.0340665    0.03315  2.68%     -    0s
#      0     0    0.03372    0    4    0.03407    0.03372  1.02%     -    0s
#      0     0    0.03372    0    4    0.03407    0.03372  1.02%     -    0s
#      0     0    0.03372    0    4    0.03407    0.03372  1.02%     -    0s
#      0     2    0.03372    0    4    0.03407    0.03372  1.02%     -    0s
#
# Explored 7 nodes (84 simplex iterations) in 0.08 seconds (0.00 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 3: 0.0340665 0.0366379 0.0376096
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.406654371085e-02, best bound 3.406654371085e-02, gap 0.0000%
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22621.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i5-13500H, instruction set [SSE2|AVX|AVX2]
# Thread count: 12 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 19 rows, 18 columns and 45 nonzeros
# Model fingerprint: 0xe58544d3
# Model has 45 quadratic objective terms
# Variable types: 9 continuous, 9 integer (9 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+02]
#   Objective range  [9e-03, 9e-01]
#   QObjective range [2e-03, 7e+01]
#   Bounds range     [1e+00, 2e+01]
#   RHS range        [6e+00, 6e+00]
# Presolve time: 0.00s
# Presolved: 19 rows, 18 columns, 45 nonzeros
# Presolved model has 45 quadratic objective terms
# Variable types: 9 continuous, 9 integer (9 binary)
# Found heuristic solution: objective 0.1164890
#
# Root relaxation: objective 1.088472e-01, 52 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.10885    0    4    0.11649    0.10885  6.56%     -    0s
# H    0     0                       0.1153188    0.10885  5.61%     -    0s
#      0     0    0.10885    0    4    0.11532    0.10885  5.61%     -    0s
#      0     0    0.10885    0    4    0.11532    0.10885  5.61%     -    0s
#      0     0    0.10885    0    4    0.11532    0.10885  5.61%     -    0s
#      0     0    0.10885    0    4    0.11532    0.10885  5.61%     -    0s
#      0     0    0.10885    0    4    0.11532    0.10885  5.61%     -    0s
#      0     0    0.11238    0    3    0.11532    0.11238  2.55%     -    0s
#      0     0    0.11238    0    3    0.11532    0.11238  2.55%     -    0s
#      0     1    0.11238    0    3    0.11532    0.11238  2.55%     -    0s
# *    1     0               1       0.1144971    0.11450  0.00%   5.0    0s
#
# Explored 2 nodes (76 simplex iterations) in 0.07 seconds (0.00 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 2: 0.114497 0.116489
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.144970778095e-01, best bound 1.144970778095e-01, gap 0.0000%
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22621.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i5-13500H, instruction set [SSE2|AVX|AVX2]
# Thread count: 12 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 19 rows, 18 columns and 45 nonzeros
# Model fingerprint: 0x71f9d35b
# Model has 45 quadratic objective terms
# Variable types: 9 continuous, 9 integer (9 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+02]
#   Objective range  [2e-03, 7e-01]
#   QObjective range [2e-03, 7e+01]
#   Bounds range     [1e+00, 2e+01]
#   RHS range        [6e+00, 6e+00]
# Presolve time: 0.00s
# Presolved: 19 rows, 18 columns, 45 nonzeros
# Presolved model has 45 quadratic objective terms
# Variable types: 9 continuous, 9 integer (9 binary)
# Found heuristic solution: objective 0.0630377
#
# Root relaxation: objective 5.819246e-02, 49 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.05819    0    4    0.06304    0.05819  7.69%     -    0s
# H    0     0                       0.0626627    0.05819  7.13%     -    0s
#      0     0    0.05898    0    4    0.06266    0.05898  5.87%     -    0s
#      0     0    0.05898    0    4    0.06266    0.05898  5.87%     -    0s
#      0     2    0.05898    0    4    0.06266    0.05898  5.87%     -    0s
# H    5     7                       0.0622074    0.05898  5.18%   3.4    0s
# *   14     9               4       0.0605677    0.05898  2.62%   3.3    0s
# H   29     3                       0.0599005    0.05935  0.91%   3.1    0s
# *   31     3               6       0.0596963    0.05954  0.27%   3.2    0s
#
# Explored 40 nodes (175 simplex iterations) in 0.12 seconds (0.00 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 5: 0.0596963 0.0605677 0.0622074 ... 0.0630377
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.969627191403e-02, best bound 5.969627191403e-02, gap 0.0000%
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22621.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i5-13500H, instruction set [SSE2|AVX|AVX2]
# Thread count: 12 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 19 rows, 18 columns and 45 nonzeros
# Model fingerprint: 0xaabb6eeb
# Model has 45 quadratic objective terms
# Variable types: 9 continuous, 9 integer (9 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+02]
#   Objective range  [5e-03, 3e-01]
#   QObjective range [2e-03, 7e+01]
#   Bounds range     [1e+00, 2e+01]
#   RHS range        [6e+00, 6e+00]
# Presolve time: 0.00s
# Presolved: 19 rows, 18 columns, 45 nonzeros
# Presolved model has 45 quadratic objective terms
# Variable types: 9 continuous, 9 integer (9 binary)
# Found heuristic solution: objective 0.0537527
#
# Root relaxation: objective 5.267909e-02, 46 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.05268    0    4    0.05375    0.05268  2.00%     -    0s
# H    0     0                       0.0536813    0.05268  1.87%     -    0s
#      0     0    0.05274    0    4    0.05368    0.05274  1.75%     -    0s
#      0     0    0.05274    0    4    0.05368    0.05274  1.75%     -    0s
#      0     0    0.05274    0    4    0.05368    0.05274  1.75%     -    0s
#      0     0    0.05274    0    4    0.05368    0.05274  1.75%     -    0s
# H    0     0                       0.0534881    0.05274  1.39%     -    0s
# H    0     0                       0.0533507    0.05274  1.14%     -    0s
#      0     2    0.05274    0    4    0.05335    0.05274  1.14%     -    0s
# *   12     0               5       0.0532039    0.05320  0.00%   3.3    0s
#
# Explored 13 nodes (97 simplex iterations) in 0.11 seconds (0.00 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 4: 0.0532039 0.0533507 0.0536813 0.0537527
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.320387834804e-02, best bound 5.320387834804e-02, gap 0.0000%
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22621.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i5-13500H, instruction set [SSE2|AVX|AVX2]
# Thread count: 12 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 19 rows, 18 columns and 45 nonzeros
# Model fingerprint: 0x0b8baba8
# Model has 45 quadratic objective terms
# Variable types: 9 continuous, 9 integer (9 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+02]
#   Objective range  [2e-02, 9e-01]
#   QObjective range [2e-03, 7e+01]
#   Bounds range     [1e+00, 2e+01]
#   RHS range        [6e+00, 6e+00]
# Presolve time: 0.00s
# Presolved: 19 rows, 18 columns, 45 nonzeros
# Presolved model has 45 quadratic objective terms
# Variable types: 9 continuous, 9 integer (9 binary)
# Found heuristic solution: objective 0.1582499
# Found heuristic solution: objective 0.1492169
#
# Root relaxation: objective 1.311270e-01, 46 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.13113    0    4    0.14922    0.13113  12.1%     -    0s
# H    0     0                       0.1397443    0.13113  6.17%     -    0s
# H    0     0                       0.1353163    0.13113  3.10%     -    0s
#      0     0    0.13419    0    4    0.13532    0.13419  0.83%     -    0s
#      0     0    0.13419    0    4    0.13532    0.13419  0.83%     -    0s
#      0     0    0.13419    0    4    0.13532    0.13419  0.83%     -    0s
#      0     0    0.13419    0    4    0.13532    0.13419  0.83%     -    0s
#      0     2    0.13419    0    4    0.13532    0.13419  0.83%     -    0s
#
# Explored 10 nodes (94 simplex iterations) in 0.10 seconds (0.00 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 3: 0.135316 0.149217 0.15825
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.353162550733e-01, best bound 1.353162550733e-01, gap 0.0000%
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22621.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i5-13500H, instruction set [SSE2|AVX|AVX2]
# Thread count: 12 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 19 rows, 18 columns and 45 nonzeros
# Model fingerprint: 0x361d7d74
# Model has 45 quadratic objective terms
# Variable types: 9 continuous, 9 integer (9 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+02]
#   Objective range  [2e-02, 2e+00]
#   QObjective range [2e-03, 7e+01]
#   Bounds range     [1e+00, 2e+01]
#   RHS range        [6e+00, 6e+00]
# Presolve time: 0.00s
# Presolved: 19 rows, 18 columns, 45 nonzeros
# Presolved model has 45 quadratic objective terms
# Variable types: 9 continuous, 9 integer (9 binary)
# Found heuristic solution: objective 0.1048313
#
# Root relaxation: objective 9.973562e-02, 44 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.09974    0    4    0.10483    0.09974  4.86%     -    0s
# H    0     0                       0.1015240    0.09974  1.76%     -    0s
#      0     0    0.09991    0    4    0.10152    0.09991  1.59%     -    0s
#      0     0    0.09991    0    4    0.10152    0.09991  1.59%     -    0s
#      0     0    0.09991    0    4    0.10152    0.09991  1.59%     -    0s
#      0     0     cutoff    0         0.10152    0.10152  0.00%     -    0s
#
# Explored 1 nodes (69 simplex iterations) in 0.08 seconds (0.00 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 2: 0.101524 0.104831
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.015239609281e-01, best bound 1.015239609281e-01, gap 0.0000%
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22621.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i5-13500H, instruction set [SSE2|AVX|AVX2]
# Thread count: 12 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 19 rows, 18 columns and 45 nonzeros
# Model fingerprint: 0x9e4a9d42
# Model has 45 quadratic objective terms
# Variable types: 9 continuous, 9 integer (9 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+02]
#   Objective range  [7e-03, 1e-01]
#   QObjective range [2e-03, 7e+01]
#   Bounds range     [1e+00, 2e+01]
#   RHS range        [6e+00, 6e+00]
# Presolve time: 0.00s
# Presolved: 19 rows, 18 columns, 45 nonzeros
# Presolved model has 45 quadratic objective terms
# Variable types: 9 continuous, 9 integer (9 binary)
# Found heuristic solution: objective 0.0827240
#
# Root relaxation: objective 7.091842e-02, 48 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.07092    0    4    0.08272    0.07092  14.3%     -    0s
# H    0     0                       0.0720931    0.07092  1.63%     -    0s
#      0     0    0.07092    0    4    0.07209    0.07092  1.63%     -    0s
#      0     0    0.07092    0    4    0.07209    0.07092  1.63%     -    0s
#      0     2    0.07092    0    4    0.07209    0.07092  1.63%     -    0s
# H    4     4                       0.0717661    0.07092  1.18%   2.8    0s
# H    5     4                       0.0713565    0.07092  0.61%   2.8    0s
#
# Explored 16 nodes (110 simplex iterations) in 0.10 seconds (0.00 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 4: 0.0713565 0.0717661 0.0720931 0.082724
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.135646823018e-02, best bound 7.135646823018e-02, gap 0.0000%
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22621.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i5-13500H, instruction set [SSE2|AVX|AVX2]
# Thread count: 12 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 19 rows, 18 columns and 45 nonzeros
# Model fingerprint: 0xafcd872f
# Model has 45 quadratic objective terms
# Variable types: 9 continuous, 9 integer (9 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+02]
#   Objective range  [9e-03, 3e+00]
#   QObjective range [2e-03, 7e+01]
#   Bounds range     [1e+00, 2e+01]
#   RHS range        [6e+00, 6e+00]
# Presolve time: 0.00s
# Presolved: 19 rows, 18 columns, 45 nonzeros
# Presolved model has 45 quadratic objective terms
# Variable types: 9 continuous, 9 integer (9 binary)
# Found heuristic solution: objective 0.3065707
#
# Root relaxation: objective 2.985214e-01, 50 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.29852    0    4    0.30657    0.29852  2.63%     -    0s
#      0     0    0.29915    0    4    0.30657    0.29915  2.42%     -    0s
#      0     0    0.29915    0    4    0.30657    0.29915  2.42%     -    0s
#      0     0    0.29915    0    4    0.30657    0.29915  2.42%     -    0s
# H    0     2                       0.3052954    0.29915  2.01%     -    0s
#      0     2    0.29915    0    4    0.30530    0.29915  2.01%     -    0s
# H    3     4                       0.3042850    0.29915  1.69%   2.3    0s
# H    4     4                       0.3042229    0.29915  1.67%   3.0    0s
# *    7     3               3       0.3009925    0.30099  0.00%   4.3    0s
#
# Explored 9 nodes (97 simplex iterations) in 0.11 seconds (0.00 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 5: 0.300992 0.304223 0.304285 ... 0.306571
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.009924572943e-01, best bound 3.009924572943e-01, gap 0.0000%
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22621.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i5-13500H, instruction set [SSE2|AVX|AVX2]
# Thread count: 12 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 19 rows, 18 columns and 45 nonzeros
# Model fingerprint: 0x9b4ee4be
# Model has 45 quadratic objective terms
# Variable types: 9 continuous, 9 integer (9 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+02]
#   Objective range  [1e-03, 5e-01]
#   QObjective range [2e-03, 7e+01]
#   Bounds range     [1e+00, 2e+01]
#   RHS range        [6e+00, 6e+00]
# Presolve time: 0.00s
# Presolved: 19 rows, 18 columns, 45 nonzeros
# Presolved model has 45 quadratic objective terms
# Variable types: 9 continuous, 9 integer (9 binary)
# Found heuristic solution: objective 0.1776895
#
# Root relaxation: objective 1.450846e-01, 50 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.14508    0    4    0.17769    0.14508  18.3%     -    0s
# H    0     0                       0.1566890    0.14508  7.41%     -    0s
# H    0     0                       0.1560836    0.14508  7.05%     -    0s
#      0     0    0.14508    0    4    0.15608    0.14508  7.05%     -    0s
#      0     2    0.14508    0    4    0.15608    0.14508  7.05%     -    0s
# H    4     6                       0.1506955    0.14508  3.72%   2.3    0s
# H   18     2                       0.1503404    0.15010  0.16%   3.1    0s
#
# Explored 21 nodes (111 simplex iterations) in 0.10 seconds (0.00 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 5: 0.15034 0.150696 0.156084 ... 0.17769
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.503403750159e-01, best bound 1.503403750159e-01, gap 0.0000%
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22621.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i5-13500H, instruction set [SSE2|AVX|AVX2]
# Thread count: 12 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 19 rows, 18 columns and 45 nonzeros
# Model fingerprint: 0xebeff196
# Model has 45 quadratic objective terms
# Variable types: 9 continuous, 9 integer (9 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+02]
#   Objective range  [2e-03, 2e-01]
#   QObjective range [2e-03, 7e+01]
#   Bounds range     [1e+00, 2e+01]
#   RHS range        [6e+00, 6e+00]
# Presolve time: 0.00s
# Presolved: 19 rows, 18 columns, 45 nonzeros
# Presolved model has 45 quadratic objective terms
# Variable types: 9 continuous, 9 integer (9 binary)
# Found heuristic solution: objective 0.0695407
#
# Root relaxation: objective 5.885491e-02, 48 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.05885    0    4    0.06954    0.05885  15.4%     -    0s
# H    0     0                       0.0695316    0.05885  15.4%     -    0s
# H    0     0                       0.0623262    0.05885  5.57%     -    0s
# H    0     0                       0.0619435    0.05885  4.99%     -    0s
#      0     0    0.06014    0    4    0.06194    0.06014  2.91%     -    0s
#      0     0    0.06014    0    4    0.06194    0.06014  2.91%     -    0s
#      0     0    0.06014    0    4    0.06194    0.06014  2.91%     -    0s
#      0     0    0.06014    0    4    0.06194    0.06014  2.91%     -    0s
#      0     0    0.06014    0    4    0.06194    0.06014  2.91%     -    0s
# H    0     2                       0.0613417    0.06014  1.96%     -    0s
#      0     2    0.06014    0    4    0.06134    0.06014  1.96%     -    0s
# *    6     1               3       0.0613000    0.06014  1.89%   3.8    0s
#
# Explored 10 nodes (96 simplex iterations) in 0.14 seconds (0.00 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 4: 0.0613 0.0619435 0.0695316 0.0695407
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.130002083220e-02, best bound 6.130002083220e-02, gap 0.0000%
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22621.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i5-13500H, instruction set [SSE2|AVX|AVX2]
# Thread count: 12 physical cores, 16 logical processors, using up to 16 threads
#
# ...
#   QObjective range [2e-03, 7e+01]
#   Bounds range     [1e+00, 2e+01]
#   RHS range        [6e+00, 6e+00]
# Presolve time: 0.00s
# Presolved: 22 rows, 19 columns, 51 nonzeros
# Presolved model has 46 quadratic objective terms
# Variable types: 10 continuous, 9 integer (9 binary)
# Found heuristic solution: objective 0.2223125
# Found heuristic solution: objective 0.2183750
#
# Root relaxation: objective 1.956969e-01, 53 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.19570    0    4    0.21837    0.19570  10.4%     -    0s
# H    0     0                       0.1998133    0.19570  2.06%     -    0s
#      0     0    0.19570    0    4    0.19981    0.19570  2.06%     -    0s
#      0     0    0.19570    0    4    0.19981    0.19570  2.06%     -    0s
#      0     0    0.19570    0    4    0.19981    0.19570  2.06%     -    0s
#      0     2    0.19570    0    4    0.19981    0.19570  2.06%     -    0s
# H    4     5                       0.1992206    0.19570  1.77%   3.5    0s
# H    5     5                       0.1983591    0.19570  1.34%   3.2    0s
#
# Explored 6 nodes (88 simplex iterations) in 0.07 seconds (0.00 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 5: 0.198359 0.199221 0.199813 ... 0.222312
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.983591140871e-01, best bound 1.983591140871e-01, gap 0.0000%
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22621.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i5-13500H, instruction set [SSE2|AVX|AVX2]
# Thread count: 12 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 19 rows, 18 columns and 45 nonzeros
# Model fingerprint: 0xe12fe392
# Model has 45 quadratic objective terms
# Variable types: 9 continuous, 9 integer (9 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+02]
#   Objective range  [4e-03, 1e+00]
#   QObjective range [2e-03, 7e+01]
#   Bounds range     [1e+00, 2e+01]
#   RHS range        [6e+00, 6e+00]
# Presolve time: 0.00s
# Presolved: 22 rows, 19 columns, 51 nonzeros
# Presolved model has 46 quadratic objective terms
# Variable types: 10 continuous, 9 integer (9 binary)
# Found heuristic solution: objective 0.0647055
#
# Root relaxation: objective 5.489772e-02, 55 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.05490    0    4    0.06471    0.05490  15.2%     -    0s
# H    0     0                       0.0646682    0.05490  15.1%     -    0s
# H    0     0                       0.0643214    0.05490  14.7%     -    0s
# H    0     0                       0.0573426    0.05490  4.26%     -    0s
# H    0     0                       0.0561009    0.05490  2.14%     -    0s
#      0     0    0.05520    0    4    0.05610    0.05520  1.61%     -    0s
#      0     0    0.05520    0    4    0.05610    0.05520  1.61%     -    0s
#      0     0    0.05520    0    4    0.05610    0.05520  1.61%     -    0s
#      0     0    0.05520    0    4    0.05610    0.05520  1.61%     -    0s
# H    0     0                       0.0559048    0.05520  1.26%     -    0s
# H    0     0                       0.0552324    0.05520  0.06%     -    0s
#
# Explored 1 nodes (70 simplex iterations) in 0.08 seconds (0.00 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 7: 0.0552324 0.0559048 0.0561009 ... 0.0647055
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.523240526875e-02, best bound 5.523240526875e-02, gap 0.0000%
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22621.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i5-13500H, instruction set [SSE2|AVX|AVX2]
# Thread count: 12 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 19 rows, 18 columns and 45 nonzeros
# Model fingerprint: 0x864ae78c
# Model has 45 quadratic objective terms
# Variable types: 9 continuous, 9 integer (9 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+02]
#   Objective range  [3e-03, 8e-01]
#   QObjective range [2e-03, 7e+01]
#   Bounds range     [1e+00, 2e+01]
#   RHS range        [6e+00, 6e+00]
# Presolve time: 0.00s
# Presolved: 22 rows, 19 columns, 51 nonzeros
# Presolved model has 46 quadratic objective terms
# Variable types: 10 continuous, 9 integer (9 binary)
# Found heuristic solution: objective 0.0611825
#
# Root relaxation: objective 5.080961e-02, 59 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.05081    0    4    0.06118    0.05081  17.0%     -    0s
# H    0     0                       0.0558538    0.05081  9.03%     -    0s
#      0     0    0.05098    0    4    0.05585    0.05098  8.73%     -    0s
#      0     0    0.05098    0    4    0.05585    0.05098  8.73%     -    0s
#      0     2    0.05098    0    4    0.05585    0.05098  8.73%     -    0s
# H    4     7                       0.0524882    0.05098  2.88%   2.8    0s
# H    5     7                       0.0512017    0.05098  0.44%   2.6    0s
#
# Explored 13 nodes (96 simplex iterations) in 0.08 seconds (0.00 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 4: 0.0512017 0.0524882 0.0558538 0.0611825
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.120173421503e-02, best bound 5.120173421503e-02, gap 0.0000%
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22621.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i5-13500H, instruction set [SSE2|AVX|AVX2]
# Thread count: 12 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 19 rows, 18 columns and 45 nonzeros
# Model fingerprint: 0x834f57a2
# Model has 45 quadratic objective terms
# Variable types: 9 continuous, 9 integer (9 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+02]
#   Objective range  [2e-05, 6e-01]
#   QObjective range [2e-03, 7e+01]
#   Bounds range     [1e+00, 2e+01]
#   RHS range        [6e+00, 6e+00]
# Presolve time: 0.00s
# Presolved: 22 rows, 19 columns, 51 nonzeros
# Presolved model has 46 quadratic objective terms
# Variable types: 10 continuous, 9 integer (9 binary)
# Found heuristic solution: objective 0.0791332
# Found heuristic solution: objective 0.0786369
#
# Root relaxation: objective 6.305323e-02, 59 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.06305    0    4    0.07864    0.06305  19.8%     -    0s
# H    0     0                       0.0709819    0.06305  11.2%     -    0s
# H    0     0                       0.0644069    0.06305  2.10%     -    0s
#      0     0    0.06377    0    4    0.06441    0.06377  0.99%     -    0s
#      0     0    0.06377    0    4    0.06441    0.06377  0.99%     -    0s
#      0     2    0.06377    0    4    0.06441    0.06377  0.99%     -    0s
#
# Explored 13 nodes (111 simplex iterations) in 0.08 seconds (0.00 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 4: 0.0644069 0.0709819 0.0786369 0.0791332
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.440686234132e-02, best bound 6.440686234132e-02, gap 0.0000%
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22621.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i5-13500H, instruction set [SSE2|AVX|AVX2]
# Thread count: 12 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 19 rows, 18 columns and 45 nonzeros
# Model fingerprint: 0x959a245f
# Model has 45 quadratic objective terms
# Variable types: 9 continuous, 9 integer (9 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+02]
#   Objective range  [6e-03, 7e-01]
#   QObjective range [2e-03, 7e+01]
#   Bounds range     [1e+00, 2e+01]
#   RHS range        [6e+00, 6e+00]
# Presolve time: 0.00s
# Presolved: 22 rows, 19 columns, 51 nonzeros
# Presolved model has 46 quadratic objective terms
# Variable types: 10 continuous, 9 integer (9 binary)
# Found heuristic solution: objective 0.0865536
# Found heuristic solution: objective 0.0735071
#
# Root relaxation: objective 6.917395e-02, 51 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.06917    0    4    0.07351    0.06917  5.89%     -    0s
#      0     0    0.06917    0    4    0.07351    0.06917  5.89%     -    0s
#      0     0    0.06917    0    4    0.07351    0.06917  5.89%     -    0s
# H    0     0                       0.0734000    0.06917  5.76%     -    0s
# H    0     0                       0.0712145    0.06917  2.87%     -    0s
#      0     2    0.06917    0    4    0.07121    0.06917  2.87%     -    0s
# H    5     4                       0.0701068    0.06917  1.33%   3.4    0s
#
# Explored 15 nodes (104 simplex iterations) in 0.07 seconds (0.00 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 4: 0.0701068 0.0712145 0.0735071 0.0865536
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.010679707645e-02, best bound 7.010679707645e-02, gap 0.0000%
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22621.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i5-13500H, instruction set [SSE2|AVX|AVX2]
# Thread count: 12 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 19 rows, 18 columns and 45 nonzeros
# Model fingerprint: 0x3f017dc4
# Model has 45 quadratic objective terms
# Variable types: 9 continuous, 9 integer (9 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+02]
#   Objective range  [2e-03, 9e-01]
#   QObjective range [2e-03, 7e+01]
#   Bounds range     [1e+00, 2e+01]
#   RHS range        [6e+00, 6e+00]
# Presolve time: 0.00s
# Presolved: 22 rows, 19 columns, 51 nonzeros
# Presolved model has 46 quadratic objective terms
# Variable types: 10 continuous, 9 integer (9 binary)
# Found heuristic solution: objective 0.0541883
#
# Root relaxation: objective 4.502685e-02, 57 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.04503    0    4    0.05419    0.04503  16.9%     -    0s
# H    0     0                       0.0513565    0.04503  12.3%     -    0s
# H    0     0                       0.0508586    0.04503  11.5%     -    0s
# H    0     0                       0.0456836    0.04503  1.44%     -    0s
#      0     0    0.04548    0    4    0.04568    0.04548  0.45%     -    0s
#      0     0    0.04548    0    4    0.04568    0.04548  0.45%     -    0s
#      0     0    0.04548    0    4    0.04568    0.04548  0.45%     -    0s
# H    0     0                       0.0456347    0.04548  0.34%     -    0s
#      0     2    0.04548    0    4    0.04563    0.04548  0.34%     -    0s
# H    7     3                       0.0456173    0.04548  0.30%   2.7    0s
# *   10     0               4       0.0456168    0.04550  0.25%   3.1    0s
#
# Explored 12 nodes (109 simplex iterations) in 0.08 seconds (0.00 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 6: 0.0456168 0.0456347 0.0456836 ... 0.0541883
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.561684613437e-02, best bound 4.561684613437e-02, gap 0.0000%
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22621.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i5-13500H, instruction set [SSE2|AVX|AVX2]
# Thread count: 12 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 19 rows, 18 columns and 45 nonzeros
# Model fingerprint: 0x474a69b6
# Model has 45 quadratic objective terms
# Variable types: 9 continuous, 9 integer (9 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+02]
#   Objective range  [9e-04, 1e+00]
#   QObjective range [2e-03, 7e+01]
#   Bounds range     [1e+00, 2e+01]
#   RHS range        [6e+00, 6e+00]
# Presolve time: 0.00s
# Presolved: 22 rows, 19 columns, 51 nonzeros
# Presolved model has 46 quadratic objective terms
# Variable types: 10 continuous, 9 integer (9 binary)
# Found heuristic solution: objective 0.0294489
#
# Root relaxation: objective 2.854917e-02, 61 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.02855    0    4    0.02945    0.02855  3.06%     -    0s
#      0     0    0.02907    0    4    0.02945    0.02907  1.28%     -    0s
#      0     0    0.02907    0    4    0.02945    0.02907  1.28%     -    0s
#      0     0    0.02938    0    2    0.02945    0.02938  0.24%     -    0s
#      0     0    0.02938    0    2    0.02945    0.02938  0.24%     -    0s
# H    0     0                       0.0294022    0.02938  0.08%     -    0s
#      0     1    0.02938    0    2    0.02940    0.02938  0.08%     -    0s
# *    1     0               1       0.0294014    0.02940  0.00%   4.0    0s
#
# Explored 2 nodes (90 simplex iterations) in 0.08 seconds (0.00 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 2: 0.0294014 0.0294489
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.940136899208e-02, best bound 2.940136899208e-02, gap 0.0000%
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22621.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i5-13500H, instruction set [SSE2|AVX|AVX2]
# Thread count: 12 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 19 rows, 18 columns and 45 nonzeros
# Model fingerprint: 0x008f5222
# Model has 45 quadratic objective terms
# Variable types: 9 continuous, 9 integer (9 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+02]
#   Objective range  [2e-03, 9e-01]
#   QObjective range [2e-03, 7e+01]
#   Bounds range     [1e+00, 2e+01]
#   RHS range        [6e+00, 6e+00]
# Presolve time: 0.00s
# Presolved: 22 rows, 19 columns, 51 nonzeros
# Presolved model has 46 quadratic objective terms
# Variable types: 10 continuous, 9 integer (9 binary)
# Found heuristic solution: objective 0.0319743
#
# Root relaxation: objective 2.808147e-02, 55 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.02808    0    4    0.03197    0.02808  12.2%     -    0s
# H    0     0                       0.0312581    0.02808  10.2%     -    0s
# H    0     0                       0.0310297    0.02808  9.50%     -    0s
# H    0     0                       0.0289795    0.02808  3.10%     -    0s
# H    0     0                       0.0289112    0.02808  2.87%     -    0s
# H    0     0                       0.0288062    0.02808  2.52%     -    0s
#      0     0    0.02817    0    4    0.02881    0.02817  2.22%     -    0s
#      0     0    0.02817    0    4    0.02881    0.02817  2.22%     -    0s
#      0     0    0.02817    0    4    0.02881    0.02817  2.22%     -    0s
#      0     2    0.02817    0    4    0.02881    0.02817  2.22%     -    0s
# H    4     5                       0.0284209    0.02817  0.89%   2.8    0s
# H    7     2                       0.0282450    0.02819  0.19%   3.0    0s
#
# Explored 11 nodes (96 simplex iterations) in 0.09 seconds (0.00 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 7: 0.028245 0.0284209 0.0288062 ... 0.0319743
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.824503215370e-02, best bound 2.824503215370e-02, gap 0.0000%
# Elasped time is 108.02689146995544 seconds
# Sharpe ratio:  0.23141499692723114
# Avg. turnover:  0.3632769013042704
